# %%
# Import Dependencies
import pandas as pd

# Create reference to CSV file
fpath = "Resources/selfscoutdata.xlsx"

pd.reset_option("all")
pd.set_option('precision', 0)

# Import the CSV into a pandas DataFrame
raw = pd.read_excel(fpath)
raw["Name"]= raw["Name"].str.split(",", n = 1, expand = True)

# ADD TEAM FILTER OPTION HERE IF THERE IS ONE ********************************************************************
#raw = raw.loc[raw["Name"] == "20 08 UTSA OFF VS FAU DEF (10/31/2020)"]
# OTHERWISE WERE SHOWING OVERALL RP

raw
# Out:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# C:\Home\SkyKing\anaconda\lib\site-packages\pandas\_config\config.py:620: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)
#        #                                        Name  Down  Distance  \
# 0      1  20 01 UTSA OFF VS TX STATE DEF (9_12_2020)     1        10
# 1      2  20 01 UTSA OFF VS TX STATE DEF (9_12_2020)     1        10
# 2      3  20 01 UTSA OFF VS TX STATE DEF (9_12_2020)     1        10
# 3      4  20 01 UTSA OFF VS TX STATE DEF (9_12_2020)     2         7
# 4      5  20 01 UTSA OFF VS TX STATE DEF (9_12_2020)     1        10
# ..   ...                                         ...   ...       ...
# 595  596      20 08 UTSA OFF VS FAU DEF (10/31/2020)     3        17
# 596  597      20 08 UTSA OFF VS FAU DEF (10/31/2020)     4        17
# 597  598      20 08 UTSA OFF VS FAU DEF (10/31/2020)     1        10
# 598  599      20 08 UTSA OFF VS FAU DEF (10/31/2020)     2        10
# 599  600      20 08 UTSA OFF VS FAU DEF (10/31/2020)     3        10
#
#      FieldPosition  Gain R/P     FORM  STR Form Fam MOTION Protection  \
# 0              -25    58   R  DOUBLES   LT      NaN    NaN        ICE
# 1               17    17   R    TURBO  NaN      NaN    NaN       FIRE
# 2              -19     3   R      DUO   LT      NaN    NaN       FIRE
# 3              -22     7   R    TURBO  NaN      NaN    NaN       FIRE
# 4              -29     0   P     TRIO   LT      NaN    NaN       BURN
# ..             ...   ...  ..      ...  ...      ...    ...        ...
# 595            -25     0   P    TRIPS   RT      NaN    NaN      BROWN
# 596            -25    -6   P    TRIPS   RT      NaN    NaN      BROWN
# 597            -25     0   P  DOUBLES   LT      NaN    NaN      BROWN
# 598            -25     0   P    DEUCE   LT      NaN    NaN      BROWN
# 599            -25    -2   P  DOUBLES   LT      NaN    NaN      BROWN
#
#            PLAY  OFF PERS  Signal pff_PASSRESULT      T FORM ADJUSTMENT  FIB  \
# 0       MUSTANG        11       2            NaN    NaN             NaN  NaN
# 1           OLE        11       3            NaN  TRIPS             NaN    X
# 2          ZACK        11       3            NaN    NaN             NaN  NaN
# 3          OZZY        11       1            NaN   TRIO             NaN  NaN
# 4         TORCH        11       2     INCOMPLETE    NaN             NaN  NaN
# ..          ...       ...     ...            ...    ...             ...  ...
# 595  VERT RACES        11       3     INCOMPLETE    NaN             NaN  NaN
# 596      INDIAN        11       3           SACK    NaN             NaN  NaN
# 597   DBL TURNS        11       3     INCOMPLETE    NaN             NaN  NaN
# 598       LEXUS        11       3     INCOMPLETE    NaN             NaN  NaN
# 599      APOLLO        11       3           SACK    NaN             NaN  NaN
#
#     Hash
# 0      L
# 1      L
# 2      L
# 3      L
# 4      R
# ..   ...
# 595    L
# 596    L
# 597    C
# 598    C
# 599    C
#
# [600 rows x 20 columns]

# %%
overallrp = raw[["FORM", "R/P",]]
run = overallrp.loc[overallrp["R/P"] == "R"]
rp = run.groupby(["FORM","R/P"])["R/P"].count().reset_index(name="R")

# %%
pas = overallrp.loc[overallrp["R/P"] == "P"]
pp = pas.groupby(["FORM","R/P"])["R/P"].count().reset_index(name="P")

# %%
mer = rp.merge(pp, on='FORM')
fin = mer[['FORM','R', 'P']]
fin = fin.set_index('FORM')
tt = fin.div(fin.sum(axis=1), axis=0)
mer = fin.merge(tt, on='FORM')
mer.rename(columns={'R_x': 'R', 'P_x': 'P', 'R_y': 'R%', 'P_y': 'P%'}, inplace=True)
mer = mer.reset_index()

# %%
#################### NEXT STEP #####################
#pd.reset_option("all")
overallrp1 = raw[["FORM", "R/P",]]

run = overallrp1[["FORM", "R/P",]]
run = run.loc[run["R/P"] == "R"]
run = run.groupby(["FORM","R/P"])["R/P"].count().reset_index(name="R")

# %%
pas1 = overallrp1.loc[overallrp1["R/P"] == "P"]
pas1 = pas1.groupby(["FORM","R/P"])["R/P"].count().reset_index(name="P")

# %%
mer1 = run.merge(pas1, on=['FORM'], how='outer')
mer1.fillna(0,inplace=True)
fin1 = mer1[['FORM','R', 'P']]
fin1 = fin1.set_index(['FORM'])
tt1 = (fin1.div(fin1.sum(axis=1), axis=0)*100).round(0).astype(str) + '%'
mer1 = fin1.merge(tt1, on=['FORM'])
mer1.rename(columns={'R_x': 'R', 'P_x': 'P', 'R_y': 'R%', 'P_y': 'P%'}, inplace=True)
#pd.options.display.float_format = '{:,.0%}'.format
mer1 = mer1.reset_index()
mer1
# Out:
#                 FORM   R   P      R%      P%
# 0                ALL   4   1   80.0%   20.0%
# 1           ALL KING  10   1   91.0%    9.0%
# 2              ALPHA   4   1   80.0%   20.0%
# 3              DEUCE   8  19   30.0%   70.0%
# 4            DOUBLES  13  47   22.0%   78.0%
# 5                DUO  47  79   37.0%   63.0%
# 6              EMPTY   1   4   20.0%   80.0%
# 7               EXIT   2   4   33.0%   67.0%
# 8              JOKER   8   1   89.0%   11.0%
# 9               KING   9  12   43.0%   57.0%
# 10             LOUIE   4   4   50.0%   50.0%
# 11         LOUIE FAR   1   1   50.0%   50.0%
# 12        LOUIE KING   3   6   33.0%   67.0%
# 13  LOUIE KING NASTY   1   0  100.0%    0.0%
# 14       LOUIE QUEEN   4   2   67.0%   33.0%
# 15         MINUTEMAN   1   0  100.0%    0.0%
# 16             QUADS   1   1   50.0%   50.0%
# 17            QUAKER   2   0  100.0%    0.0%
# 18             ROGER   6  12   33.0%   67.0%
# 19         ROGER FAR   1   1   50.0%   50.0%
# 20        ROGER KING   9   9   50.0%   50.0%
# 21  ROGER KING NASTY   1   0  100.0%    0.0%
# 22       ROGER QUEEN   7   0  100.0%    0.0%
# 23              TREY  20   9   69.0%   31.0%
# 24              TRIO  47  53   47.0%   53.0%
# 25             TRIPS   7  28   20.0%   80.0%
# 26             TROOP   2   0  100.0%    0.0%
# 27              TROY   5   1   83.0%   17.0%
# 28             TURBO  34  26   57.0%   43.0%
# 29           0 TRIPS   0   1    0.0%  100.0%
# 30     9 LOUIE NASTY   0   1    0.0%  100.0%
# 31               ACE   0   2    0.0%  100.0%
# 32        FLIP TRIPS   0   1    0.0%  100.0%
# 33     JOKER SQUEEZE   0   1    0.0%  100.0%
# 34             QUEEN   0   1    0.0%  100.0%
# 35            SAINTS   0   1    0.0%  100.0%
# 36             SPLIT   0   1    0.0%  100.0%
# 37             TRIBE   0   6    0.0%  100.0%
